# %% [markdown]
# <a href="https://colab.research.google.com/github/avi-guha/ENPH-353-COMPETITION/blob/clue-board-reading/353_Clueboard_Reader_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ENPH 353: CLUEBOARD READER NN
#
# November 10, 2025
#
# Ella Majkic

# %%
import string
import cv2
import numpy as np
import os
from tensorflow import keras
print('Success')
# Out:
# Success
